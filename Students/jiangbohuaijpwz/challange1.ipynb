# %%
import numpy as np
import matplotlib.pyplot as plt
def g(t):
    return 1 - (np.exp(-2*t) * np.cos(np.pi*t))

t1 = np.arange(0.0, 2.0, 0.01)

plt.figure(1)
plt.plot(t1, g(t1), 'r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def g(t):
    return 1 - (np.exp(-2*t) * np.cos(np.pi*t))
def f(t,a):
    return 1-(np.exp(-a*t))

a2=np.arange(0.0,10.0,0.0001)

mina=0
mse=0
rmse=0
minN=100

for a in a2:
    N=sum(((f(t1,a)-g(t1)))**2)**0.5
    if N<minN:  
        minN=N
        mina=a
        
mse=(minN*minN)/len(t1)
rmse=np.sqrt(mse)

#results are as followed

print("The valus of min a is ",mina)
print("The value of L2 norm between f(t) and g(t) ",minN)
print("The value of mse is",mse)
print("The value of rmse is",rmse)


plt.figure(1)
plot1=plt.plot(t1, g(t2), 'b',label='g(t)')
plot2=plt.plot(t1, f(t2,mina), 'r',label='f(t)')
plt.legend()
plt.xlabel('t')
plt.ylabel('codomain')
plt.show()
# Out:
# The valus of min a is  4.6035
# The value of L2 norm between f(t) and g(t)  1.50453869935
# The value of mse is 0.0113181834891
# The value of rmse is 0.106386951686
