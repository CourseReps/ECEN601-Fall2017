# %%
import numpy as np
import matplotlib.pyplot as plt
def g(t):
    return 1 - (np.exp(-2*t) * np.cos(np.pi*t))

t1 = np.arange(0.0, 2.0, 0.01)

plt.figure(1)
plt.plot(t1, g(t1), 'r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def g(t):
    return 1 - (np.exp(-2*t) * np.cos(np.pi*t))
def f(t,a):
    return 1-(np.exp(-a*t))

a1=np.arange(0.0,10.0,0.0001)

besta=0
error=0
minN=100

for a in a1:
    N=sum(((f(t1,a)-g(t1)))**2)**0.5   #accornding to the definition of L2 norm
    if N<minN:  
        minN=N
        besta=a
        
error=(minN*minN)/len(t1)

#results are as followed

print("The valus of minimum a is ",besta)
print("The value of L2 norm between f(t) and g(t) ",minN)
print("The value of residual mean squared error is",error)



plt.figure(1)
plot1=plt.plot(t1, g(t2), 'b',label='g(t)')
plot2=plt.plot(t1, f(t2,mina), 'r',label='f(t)')
plt.legend()
plt.show()
# Out:
# The valus of minimum a is  4.6035
# The value of L2 norm between f(t) and g(t)  1.50453869935
# The value of residual mean squared error is 0.0113181834891

# %%
# method to get a:
# firstly, I assume a is smaller than 10. Then under a specific value of each a, I calculate the L2 norm by the definition.
#  Then I compare the L2 norm at different value of a to get the value of a.
