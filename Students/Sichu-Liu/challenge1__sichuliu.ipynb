# %%
print('Here is my solution')
# Out:
# Here is my solution

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def g(t):
    return 1 - (np.exp(-2*t) * np.cos(np.pi*t))

plt.figure(1)
plt.plot(t1,g(t1),'k')
plt.show()

def f(a ,t):
    return 1- (np.exp(-a*t))

t1 = np.arange(0.0, 2.0, 0.01)
a1 = np.arange(0.0, 20.0, 0.001)

   
def L(a):
    err = (np.sum((g(t1)-f(a,t1))**2))**0.5
    return err

minerr = L(0)

for a in (a1):
    if L(a)<minerr:
        minerr=L(a)
        mina=a

print("The Value of a that minimizes the L2 norm between  g(t) and f(t) over the interval [0, 2] is ： %f "%mina)
Sqerror = minerr / len(t1)
print("The residential mean squared error is : %f"%Sqerror)
# Out:
# The Value of a that minimizes the L2 norm between  g(t) and f(t) over the interval [0, 2] is ： 4.603000
# The residential mean squared error is : 0.007523

# %%
plt.figure(2)
plt.xlabel('t')
plt.ylabel('g,f')
plt.plot(t1, g(t1) , label='g(t)')
plt.plot(t1, f(mina,t1) , label='f(t)')
plt.show()

# %%
print("To obtain a, I calculate the result of L(a) of a value between 0-20. After finding the minimum L(a), I get a. ")
# Out:
# To obtain a, I calculate the result of L(a) of a value between 0-20. After finding the minimum L(a), I get a.
