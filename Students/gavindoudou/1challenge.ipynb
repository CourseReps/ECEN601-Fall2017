# %% [markdown]
# # Challenge 1
#
# ## SciPy Tutorial
# Pertinent information about [SciPy](https://docs.scipy.org/) and NumPy is available in the [SciPy Tutorial](https://docs.scipy.org/doc/scipy/reference/tutorial/index.html).
#  * Read [Introduction](https://docs.scipy.org/doc/scipy/reference/tutorial/general.html)
#  * Read [Basic functions](https://docs.scipy.org/doc/scipy/reference/tutorial/basic.html)
#  * Read [Optimization](https://docs.scipy.org/doc/scipy/reference/tutorial/optimize.html)
#
# Consider the function defined below.
#  * Plot the function using [matplotlib](https://matplotlib.org/)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def g(t):
    return 1 - (np.exp(-2*t) * np.cos(np.pi*t))

t1 = np.arange(0.0, 2.0, 0.01)

plt.figure(1)
plt.plot(t1, g(t1), 'k')
plt.show()
# Out:
# E:\ANACONDA\lib\site-packages\matplotlib\axis.py:1035: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "

# %% [markdown]
# Consider the class of functions of the form $f(t) = 1 - e^{-at}$ where $a$ is a free parameter.
#  * Find the value of $a$ that minimizes the $L_2$ norm between $g(t)$ and $f(t)$ over the interval $[0, 2]$
#  * Computer the residual mean squared error
#  * Explain how you obtained $a$

# %%
import numpy as np
import matplotlib.pyplot as plt

t1 = np.arange(0, 2, 0.01)
aran = np.arange(-100,100,0.001)
L2norm=1000.0
mina=0.0
rmse=1000.0


def g(t):
    return 1 - (np.exp(-2*t) * np.cos(np.pi*t))
def f(t,a):
    return 1 - np.exp(-a*t)

for a in aran:
    if L2norm > np.sum((g(t1)-f(t1,a))**2)**0.5:
        L2norm = np.sum((g(t1)-f(t1,a))**2)**0.5
        mina=a
        rmse=L2norm**2/len(t1)

print("Value of a:  ",mina)
print("L2 norm between g(t) and f(t):  ",L2norm)
print("Residual mean squared error  ",rmse) 

plt.figure(2)
plt.plot(t1, g(t1), 'k',label='g(t)')
plt.plot(t1, f(t1,mina), 'r',label='f(t)')
plt.legend()
plt.show()
# Out:
# Value of a:   4.6030000005
# L2 norm between g(t) and f(t):   1.50453872768
# Residual mean squared error   0.0113181839155

# %% [markdown]
# 1. I set an "a" range from -100 to 100 with accuracy of 0.001 to calculate the L2 norm of between g(t) and f(t)
# 2. When the norm is smaller than the previous one, the program will renew the "a" value and write down the norm value.
# 3. l calculate the resdiual mean squared error.
